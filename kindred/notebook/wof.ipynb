# %%
import pandas as pd
import numpy as np

file= open("EPL_2018_2019.csv",mode="r", encoding="utf-8"  )
data = pd.read_csv(file)
data_np = np.array(data)
print(data_np)
# Out:
# [[1533927600 'Aug 10 2018 - 7:00pm' 'complete' ... 2.05 1.69
#   'Old Trafford (Manchester)']
#  [1533987000 'Aug 11 2018 - 11:30am' 'complete' ... 1.83 1.87
#   "St. James' Park (Newcastle upon Tyne)"]
#  [1533996000 'Aug 11 2018 - 2:00pm' 'complete' ... 1.83 1.83
#   'Vitality Stadium (Bournemouth- Dorset)']
#  ...
#  [1557669600 'May 12 2019 - 2:00pm' 'complete' ... 1.8 2.0
#   "St. Mary's Stadium (Southampton- Hampshire)"]
#  [1557669600 'May 12 2019 - 2:00pm' 'complete' ... 1.59 2.3
#   'Tottenham Hotspur Stadium (London)']
#  [1557669600 'May 12 2019 - 2:00pm' 'complete' ... 1.48 2.55
#   'Vicarage Road (Watford)']]
